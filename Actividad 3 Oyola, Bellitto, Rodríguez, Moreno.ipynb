# %% [markdown]
# # Prácticas Profesionalizantes 2024
# EEST 9
#
# # Actividad 3

# %% [markdown]
# ## Trabajo en grupo entre 2 o 3 estudiantes
# Indicar los nombres y los links de los repositorios de la actividad 2 de los integrantes:
# * Lea - https://github.com/Oyola345/mi_hobby/tree/main
# * Tobías - https://github.com/Toberrrr/mi_hobby?authuser=0
# * Valentino - https://github.com/VainillaSheep/mi_hobby/blob/main/mi_hobby.md
# * Bautista -

# %% [markdown]
# # Python y Colab
# * Se utilizará **Python** y este documento de **Google Colab** para resolver el ejercicio.
# * Para que la tarea se considere entregada se deberá poner el link del documento colab, con las soluciones, en la tarea de **todos** los integrantes.
#
# El ejercicio es **procesar texto** largo para identificar líneas, caracteres específicos y generar un diccionario con los nombres de los integrantes.
#
# 1. Se deberá realizar una **copia** de este documento antes de comenzar a modificar
# 2. A lo largo del documetno se pedirá que responda preguntas y realice código, completar en la copia realizada con lo solicitado.
# 3. Copiar el texto de los archivos subidos en los repositorios individuales utilizados en la actividad 1,  de cada integrante de este grupo en una sola **variable de texto.**
# 4. Antes del texto de cada integrante se deberá poner el nombre correspondiente y luego agregar el caracter *

# %% [markdown]
# Respetar el siguiente formato del texto para guardarlo de esa forma en la variable:
#
# Nombre1*
#
# Título:
#
# Diversión:
#
# Familia:
#
# Amigos:
#
# Medios:
#
# Tecnología:
#
# Nombre2*

# %%
# completar con sus textos
texto_completo = '''Lea*
Titulo: Bailar KPOP
Diversión: Me gusta bailar Kpop (Pop coreano) porque puedo elegir entre coreografías sencillas o complejas y es divertido cuando por fin te sale una secuencia de pasos que no entendías como los hacen los grupos. Además al ser una música y cultura distinta a la nuestra, así también es su baile, así que es algo nuevo y entretenido.

Familia: En mi familia soy la única que baila Kpop, a veces les enseño algunos pasos, pero soy la única que lo tiene como hobby.

Amigos: Tampoco tengo amigos que bailen Kpop, pero al igual que a mi familia, a veces les enseño algún paso.

Medios: Aprendo viendo e imitando los videos de las coreografías en YouTube.

Tecnología: La tecnología facilitó el accesso a poder bailar Kpop en dos sentidos:

En primer lugar posibilitó el acceso al género musical desde esta parte del mundo y se logró en gran parte gracias a YouTube. El Kpop se popularizó fuera de Corea del Sur, y de sus alrededores, con la canción que fue un éxito en su momento: "Gangnam Style" de PSY (en 2012, 7 años después de la aparición de YouTube).

Y en segundo lugar, posibilitó el acceso a los llamados "Dance Practice" que son las coreografías que suben los grupos a la plataforma para que sus fanáticos puedan aprender las mismas coreos que ellos hacen en el escenario.

Creo que se ha expandido mucho este género musical y hay más chicos y chicas que escuchan Kpop, pero para bailarlo todavía son más mujeres que hombres que les guste.

Valentino*
Titulo: Programación de videojuegos y aplicaciones

Diversión: Me empece a interesar por la programación y la informática gracias a los videojuegos, uno de mis sueños desde chico es crear uno y con los años también me empezó a interesar también trabajar en el desarrollo de aplicaciones.

Familia: Ningún miembro de mi familia se dedico a este hobby, mi papa esta un poco interesado en aprender y mi primo tiene ganas de aprender sobre todo informática para arreglar computadoras.

Amigos: Se podría decir que 3 o 4 veces a la semana generalmente cuando nos encontramos en la escuela y trabajamos en proyectos o nos ayudamos en el tema cada uno desde su casa.

Medios: Youtube y twitter son las principales redes sociales en las que suelo ver contenido de programación, generalmente de videojuegos. También cuando suelo descargar modificaciones de videojuegos me gusta ver el código, (si esta disponible) para ver como están programadas.

Tecnología: Con el avance de los años y de las tecnologías se fue haciendo cada vez mas accesible para las personas el poder adentrarse en la programación. En sus inicios era algo muy complicado que pocos estaban dispuestos a aprender por lo limitado de la tecnología y lo complicado de los lenguajes de antes. No se puede saber con certeza que diferencia de cantidad de programadores hombres y mujeres hay, existe el estereotipo de que el programador solía ser hombre y había pocas mujeres en el ámbito y aunque puede que haya sido así hace varios años por cuestiones de la época, la realidad es que esto actualmente a cambiado y es mucho mas común ver tanto mujeres como hombres en el ámbito informático.

Bautista*
Titulo: Jugar en la pc

Diversión: siento que con algunos juegos logro distraerme mucho y relajarme, mientras que en otros logro una concentracion plena para saber todo lo que esta pasando al mismo tiempo

Familia: lamentablemente este hobby no lo comparto con nadie de la familia

Amigos: entre 2 y 3 dias

Medios: mas que nada en youtube

Tecnología: gracias a la tecnologia puedo realizar este hobby ya que se basa exclusivamente en ella, desconozco si es realizado por igual manera entre hombres y mujeres ya que por mas que sea mi hobby no consumo contenido de ello

Tobías*
Titulo: Gaming en pc

Diversión: es un hobby que me es muy entretenido y que es un mercado muy grande donde hay muchisimos videojuegos todos los meses.

Familia: Antes lo compartia con mi hermano, pero ahora juego con amigos nada mas

Amigos: Lo comparto casi todos los dias, una o dos horas

Medios: Busco en google o youtube, si no en foros pero youtube es de donde saco mas informacion para los videojuegos.

Tecnología: La tecnlogia para los videojuegos a sido de mucha importancia ya que la evolucion de los graficos, mecanicas y demas temas tecnico, son gracias a estos avances que se han echo en mas de 30 años de mercado, y con respecto a la igualdad en los videojuegos, siempre la hubo, pero no hay estadisticas o estudios que den esa informacion sobre si es realizado tanto por varones o por mujeres
'''

# %% [markdown]
# ## Procesamiento
# * Procesar la variable de texto y generar una estructura que permita acceder directamente con el nombre del integrante:
#
# **Nombre1**: **texto del hobby**
# * Nota: Para guardar la key con el nombre preguntar si en la línea contiene el caracter "*"

# %% [markdown]
# Para poder concatenar texto debo ir agregando los textos de cada linea, les dejo un ejemplo

# %%
contenido = ''
contenido = contenido + 'hola'
contenido
# Out:
# 'hola'

# %%
contenido = contenido + ' mas texto'
contenido
# Out:
# 'holamas texto'

# %%
#separo en líneas la variable de texto
textoSeparado = texto_completo.splitlines()

#creo mi diccionario

mi_dict = {}

# recorro la variable con los elementos, encontrando las líneas que contiene el caracter *

for i in textoSeparado:
  if "*" in i:
    integrante = i.replace('*', '')
    mi_dict[integrante] = ''
  else:
    mi_dict[integrante] = mi_dict[integrante]+' '+ i

print(mi_dict)

# si la linea no contiene * voy agregando a una variable de texto el contenido de ese hobby
# Out:
# {'Lea': ' Titulo: Bailar KPOP Diversión: Me gusta bailar Kpop (Pop coreano) porque puedo elegir entre coreografías sencillas o complejas y es divertido cuando por fin te sale una secuencia de pasos que no entendías como los hacen los grupos. Además al ser una música y cultura distinta a la nuestra, así también es su baile, así que es algo nuevo y entretenido.  Familia: En mi familia soy la única que baila Kpop, a veces les enseño algunos pasos, pero soy la única que lo tiene como hobby.  Amigos: Tampoco tengo amigos que bailen Kpop, pero al igual que a mi familia, a veces les enseño algún paso.  Medios: Aprendo viendo e imitando los videos de las coreografías en YouTube.  Tecnología: La tecnología facilitó el accesso a poder bailar Kpop en dos sentidos:  En primer lugar posibilitó el acceso al género musical desde esta parte del mundo y se logró en gran parte gracias a YouTube. El Kpop se popularizó fuera de Corea del Sur, y de sus alrededores, con la canción que fue un éxito en su m
# ...

# %% [markdown]
# * Indicar cuáles son las keys y cuáles los valores del diccionario

# %%
#completar con el ćodigo
#Muestra las keys
for integrante in mi_dict:
  print(integrante)

#Muestra los value
for integrante in mi_dict:
  print(mi_dict[integrante])
# Out:
# Lea
# Valentino
# Bautista
# Tobías
# ...

# %% [markdown]
# * Indicar la longitud del diccionario

# %%
#completar con el código para indicar la longitud

#Muestra La cantidad de caracteres de cada value
for integrante in mi_dict:
  print(len(mi_dict[integrante]))

print('')

#Muestra los caracteres de cada key
for integrante in mi_dict:
  print(len(integrante))

#Muestra la cantidad de elementos del diccionario
print('')
print(len(mi_dict))
# Out:
# 1467
# 1647
# 572
# 810
#
# 3
# 9
# 8
# 6
#
# 4

# %% [markdown]
# * Indicar qué integrante tiene el texto más largo.
#
# Completar el código para encontrar la solución

# %%
# recorro el diccionario
#consulto si el valor asociado en esa key es mayor que un valor maximo
# si es mayor actualizo la variable

integranteMayor = 0

for integrante in mi_dict:
    if len(mi_dict[integrante]) > integranteMayor:
      integranteMayor=len(mi_dict[integrante])
      keyInte=integrante

print("El integrante con el texto más largo es: " + keyInte)
print(integranteMayor)
# Out:
# El integrante con el texto más largo es: Valentino
# 1647

# %% [markdown]
# ### Contestar
# 1. Indicar qué tipos de datos se utilizaron en este documento.
#
# Respuesta: Strings, int.
#
#
# 2. Por cada tipo de datos de los ejemplos, indique cuáles son las variables utilizadas en esta actividad de ese tipo.
#
# Respuesta: String: texto_completo, texto_Separado, key_inte, textocompleto, comentario
#
# Int: integranteMayor
#
#
# 3. ¿Qué estructuras de datos que permite almacenar más de un elemento, utilizó en esta actividad? De los nombres de las variables que correspondan a este tipo de datos.
#
# Respuesta: La estructura de datos que permite almacenar más de un elemento son las listas y diccionarios, en esta actividad se utilizó diccionario.
# La variable que corresponde al diccionario es mi_dict
#
# 4. ¿Qué estructuras de control utilizó?
#
# Respuesta: Usamos las estructuras `if`, `else` y `for`
#
#
# 5. Investigar en chatgpt: ¿Qué tipos de archivos se pueden utilizar para guardar datos? Indique los formatos y las librerías que deben importarse para poder usar.
#
# Respuesta: "Claro, aquí tienes una lista de tipos de archivos comunes para guardar datos junto con las librerías en Python que puedes importar para trabajar con ellos:
#
# 1. **Archivos de texto**:
#    - Formatos: .txt, .csv, .json, .xml
#    - Librerías:
#      - Para archivos CSV: `import csv`
#      - Para archivos JSON: `import json`
#      - Para archivos XML: `import xml.etree.ElementTree`
#
# 2. **Archivos de hoja de cálculo**:
#    - Formatos: .xlsx (Excel), .ods (OpenDocument Spreadsheet)
#    - Librerías:
#      - Para archivos Excel (.xlsx): `import openpyxl`
#      - Para archivos OpenDocument Spreadsheet (.ods): `import ezodf`
#
# 3. **Bases de datos**:
#    - Formatos: .sqlite, .mdb (Access), .dbf
#    - Librerías:
#      - Para SQLite: `import sqlite3`
#      - Para bases de datos de Access (.mdb): `import pyodbc`
#      - Para archivos DBF: `import dbf`
#
# 4. **Archivos binarios**:
#    - Formatos: .bin, .dat
#    - Librerías:
#      - Python proporciona herramientas estándar para trabajar con archivos binarios, como los módulos `struct` y `pickle`.
#
# 5. **Archivos de imagen y video**:
#    - Formatos: .jpg, .png, .gif, .mp4, .avi
#    - Librerías:
#      - Para imágenes: `import PIL` (Python Imaging Library)
#      - Para video: `import cv2` (OpenCV)
#
# 6. **Archivos de audio**:
#    - Formatos: .mp3, .wav, .ogg
#    - Librerías:
#      - Para trabajar con archivos de audio: `import librosa` (para análisis de señales de audio)
#
# 7. **Archivos de documentos**:
#    - Formatos: .docx (Word), .pdf, .pptx (PowerPoint)
#    - Librerías:
#      - Para archivos PDF: `import PyPDF2`, `import pdfplumber` (para extraer texto e información de PDFs)
#      - Para archivos DOCX: `import docx`"
